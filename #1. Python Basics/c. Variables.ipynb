# %% [markdown]
# # Python Variables

# %%
a = "Python"
b= 5
print(a)
print(b)
print(a,b)
# Out:
# Python
# 5
# Python 5

# %%
n1 = 10       # n is of type int
n1= "Apple"  # n1 is now of type str
n1= 10.5      # n1 is now of float type
print(n1)
# Out:
# 10.5

# %% [markdown]
# # Specify or Knowing the data type of variable

# %%
x = str(10)    # x will be '10'
y = int(10)    # y will be 10
z = float(10)  # z will be 10.0
print(x)
print(y)
print(z)
print(x, y, z)
# Out:
# 10
# 10
# 10.0
# 10 10 10.0

# %% [markdown]
# # Rules for Variable Names
#
# A variable name must start with a letter or the underscore character<br>
# A variable name cannot start with a number<br>
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )<br>
# Variable names are case-sensitive (age, Age and AGE are three different variables)<br>
# A variable name cannot be any of the Python keywords.

# %%
avar = "Python code"
a_var = "Python code"
_var = "Python code"
aVar = "Python code"
AVAR = "Python code"
avar1 = "Python code"

# %% [markdown]
# # Wrong Variables

# %%
#2myvar = "John"
#my-var = "John"
#my var = "John"

# %% [markdown]
# Note - Variable names are case-sensitive

# %% [markdown]
# # Assign Values to Multiple Variable at a time

# %%
x, y, z = "Python", "Program", 2
print(x)
print(y)
print(z)
print(x, y, z)
# Out:
# Python
# Program
# 2
# Python Program 2

# %%
x = y = z = "Python"
print(x)
print(y)
print(z)
print(x, y, z)
# Out:
# Python
# Python
# Python
# Python Python Python

# %%
words = ["Python", "Program", "Code"] # list of words
x, y, z = words
print(x)
print(y)
print(z)
print(x, y, z)
print(words)
# Out:
# Python
# Program
# Code
# Python Program Code
# ['Python', 'Program', 'Code']

# %% [markdown]
# + +Operator

# %%
x = "Python"
y = "is"
z = "interesting"
print(x + y + z)
# Out:
# Pythonisinteresting

# %%
x = "Python "
y = "is "
z = "interesting"
print(x + y + z)
# Out:
# Python is interesting

# %%
x = "Hello"
y = 10
print(x + str(y))
# Out:
# Hello10

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
x= 'I '
y= 'like '
z= 'python '
print (x+y+z)
# Out:
# I like python

# %%
x = "Hello"
y = 10
print(x +str(y))
# Out:
# Hello10
