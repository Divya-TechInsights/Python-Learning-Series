# %% [markdown]
# ## Change Dictionary Items

# %% [markdown]
# ### Change Values
# You can change the value of a specific item by referring to its key name

# %%
dict1 = {"brand": "Ford", "model": "Mustang", "year": 1964}

dict1["year"] = 2018
print(dict1)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2018}

# %% [markdown]
# ### update() Method
#
# The update() method adds key-value pairs from another dictionary or an iterable of key-value pairs to the current dictionary.
#
# If the key already exists, its value will be overwritten.
#
# If the key does not exist, it will be added.

# %% [markdown]
# ### 1: Updating with another dictionary

# %%
person1 = {"name": "Alice", "age": 25}
person2 = {"age": 26, "city": "New York"}

person1.update(person2)
print(person1)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'New York'}

# %% [markdown]
# age was updated from 25 → 26
#
# city was added as a new key

# %% [markdown]
# ### 2: Updating with a list of tuples

# %%
person = {"name": "Bob"}
list_of_tuples = [("age", 30), ("country", "India")]
person.update(list_of_tuples)
print(person)
# Out:
# {'name': 'Bob', 'age': 30, 'country': 'India'}

# %% [markdown]
# ### 3: List of lists

# %%
person = {"name": "Alice"}
person.update([["age", 25], ["city", "London"]])
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'London'}

# %% [markdown]
# ### 4: Tuple of tuples

# %%
person = {"name": "Bob"}
person.update((("age", 30), ("country", "India")))
print(person)
# Out:
# {'name': 'Bob', 'age': 30, 'country': 'India'}

# %% [markdown]
# ### 5: Set of tuples

# %%
person = {"name": "Charlie"}
person.update({("age", 28), ("city", "Paris")})
print(person)
# Out:
# {'name': 'Charlie', 'age': 28, 'city': 'Paris'}

# %% [markdown]
# Only works if each element is a tuple with exactly 2 items (key, value).
