# %% [markdown]
# | Feature               | List                         | Tuple                              | Set                         | Frozenset                         | Dictionary                       |
# | --------------------- | ---------------------------- | ---------------------------------- | --------------------------- | --------------------------------- | -------------------------------- |
# | Meaning               | Ordered collection of values | Ordered fixed collection of values | Collection of unique values | Fixed collection of unique values | Collection of key–value pairs    |
# | Order                 | Maintains insertion order    | Maintains insertion order          | Does not maintain order     | Does not maintain order           | Maintains insertion order        |
# | Changeable            | Can be modified              | Cannot be modified                 | Can be modified             | Cannot be modified                | Can be modified                  |
# | Duplicates            | Allowed                      | Allowed                            | Not allowed                 | Not allowed                       | Keys not allowed, values allowed |
# | Access Method         | Index-based                  | Index-based                        | No index                    | No index                          | Using keys                       |
# | Syntax                | Square brackets              | Parentheses                        | Curly brackets              | `frozenset()`                     | Curly brackets with key:value    |
# | Use as Dictionary Key | Cannot be used               | Can be used                        | Cannot be used              | Can be used                       | Cannot be used                   |
# | Nesting               | Allowed                      | Allowed                            | Not allowed                 | Not allowed                       | Allowed                          |
# | Performance           | Slower than tuple            | Faster than list                   | Fast membership checking    | Fast membership checking          | Fast key-based lookup            |
# | Common Use            | Dynamic data storage         | Fixed data storage                 | Removing duplicates         | Immutable unique data             | Mapping related data             |
